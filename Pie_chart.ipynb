# %%
## -*- coding:utf-8 -*-

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['font.sans-serif']=['SimHei']
mpl.rcParams['axes.unicode_minus']=False
mpl.rcParams['font.size'] = 10

plt.style.use('seaborn-paper')

fig, ax = plt.subplots(figsize=(12, 7))

# tick_labels = ['Real estate and hospitality', 'Transport and infrastructure', 
#                 'Health and biotech', 'Information and communications technology', 'Finance and business services',
#                'Entertainment', 'Automotive', 'Electronics + Agriculture and food + Basic materials + \
#                Industrial machinery and equipment + Aviation + Consumer products and services + Energy']

tick_labels = (['房地产与酒店服务', '交通与基建', '医疗保健与生物科技', '信息与通讯技术', '金融与商业服务',
               '娱乐', '汽车', '其他'])

#(电子+农业与食物+原材料+工业机械设备+航空+消费品与服务+能源)

numbers = [11000, 10400, 2500, 2500, 1300, 524, 437, 701]
explode = [0.1, 0, 0, 0, 0, 0, 0, 0]

#plt.legend(numbers, tick_labels, fontsize=12, title='投资领域', loc='center left', bbox_to_anchor=(1.2, 0, 0.3, 1))

plt.title('中国2017年在美国各领域的直接投资比例', size=20)

plt.pie(x = numbers, labels = tick_labels, autopct = '%.1f%%', 
                           explode = explode, shadow = True, textprops={'fontsize': 14})
plt.show()
